# %% [markdown]
# ## Database connection

# %%
from pymongo import MongoClient

# %% [markdown]
# Connect to our database:

# %%
client = MongoClient()
db = client.asi_database
c = db.asi_collection

# %% [markdown]
# Some basic counts:

# %%
from os import listdir
IMAGES_DIR = '/home/ryan/asi_images/' #full images under the 'full' subdirectory
print 'Number of unique lots: %d' % c.count()
print 'Number of unique artists: %d' % len(c.distinct('artistID'))
print 'Number of images scraped: %d' % len(listdir(IMAGES_DIR + 'full/'))
#print 'Number of distinct art titles: %d' % len(c.distinct('artTitle'))
# Out:
# Number of unique lots: 1355571
# Number of unique artists: 122005
# Number of images scraped: 500039

# %% [markdown]
# Scraping efficiency (total lots over highest lot ID retrieved):

# %%
print 'Scraping efficiency: %f' % (c.count()/float(max(c.distinct('lot_id'))))
# Out:
# Scraping efficiency: 0.769352

# %% [markdown]
# Largest Lot ID:

# %%
max(c.distinct('lot_id'))
# Out:
# 1761965

# %% [markdown]
# ## Artist Data

# %% [markdown]
# Select a random subset of artists and make a pandas dataframe of all their auction lots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Image
# %matplotlib inline
N_ARTISTS = 2000

#grab a few artists
artists = np.random.choice(c.distinct('artistID'), N_ARTISTS)
#make MongoDB cursor
cursor = c.find({'artistID':{'$in':list(artists)}})
df = pd.DataFrame(list(cursor))
del df['_id']

print 'Loaded %d lots belonging to %d artists.' % (df.shape[0], N_ARTISTS)
# Out:
# Loaded 24372 lots belonging to 2000 artists.

# %%
df.artistNationality.value_counts().ix[:50].plot(kind='bar', figsize=(12,4))
plt.title('Artist Nationalities')

# %%
print 'Most sold artists by total lots:'
top_artists = df.artistName.value_counts().ix[:10].index.values
df.artistName.value_counts().ix[:10]
# Out:
# Most sold artists by total lots:
# Rembrandt Harmensz van Rijn    1433
# Henri Lebasque                  836
# George Grosz                    763
# Andre Masson                    674
# Sir Hans Heysen                 423
# Antoni Tapies                   422
# Wilhelm von Gegerfelt           352
# Patrick Leonard                 346
# Paul Gauguin                    346
# Qi Baishi                       325
# dtype: int64

# %%
print 'Most sold art title by total lots:'
df.artTitle.value_counts().ix[:10]
# Out:
# Most sold art title by total lots:
# Untitled              422
# Composition           254
# Landscape              97
# Achrome                92
# Still life             71
# Paysage                64
# Sans titre             52
# Nature morte           39
# Raising of Lazarus     38
# Nude                   32
# dtype: int64

# %%
dfat = df[['artistName', 'artTitle']]
dfat = dfat[dfat['artistName'].isin(top_artists)]
dfat['count'] = 1
top_artist_painting = []
print "Most sold art titles by top artists"
for i in range(len(top_artists[:5])):
    top = dfat.groupby(['artistName', 'artTitle']).sum().ix[top_artists[i]].sort('count',ascending=False).ix[:5]
    top_artist_painting.append((top_artists[i], top.ix[0].name))
    print '\n'
    print top_artists[i]
    print top
# Out:
# Most sold art titles by top artists
#
#
# Rembrandt Harmensz van Rijn
#                             count
# artTitle
# Raising of Lazarus             38
# Return of the Prodigal Son     24
# Death of the Virgin            22
# Descent from the cross         21
# Christ preaching               19
# Henri Lebasque
#                 count
# artTitle
# Nu allonge         18
# Sur la plage       18
# Paysage            16
# Vase de fleurs      9
# Nu                  8
#
#
# George Grosz
#                       count
# artTitle
# Nude                     13
# Street scene             12
# Standing female nude     11
# Female nude              11
# Reclining nude            9
# Andre Masson
#               count
# artTitle
# Composition      22
# Untitled         20
# Sans titre       12
# Paysage           6
# Metamorphose      5
# Sir Hans Heysen
#                      count
# artTitle
# Ambleside landscape     12
# White gums               6
# Flinders Ranges          5
# Flinders ranges          4
# Landscape                4

# %%
def artist_plot(artist):
    fig, ax = plt.subplots(1,2)
    artist_price_trend = df[df['artistName']==artist][['auctionDate','priceUSD']]
    artist_price_trend['auctionDate'] = pd.to_datetime(artist_price_trend['auctionDate'])
    artist_price_trend.index = artist_price_trend['auctionDate']
    ix = np.unravel_index(0, ax.shape)
    artist_price_trend.ix['2002':].plot(ax=ax[ix], figsize=(12,4))
    #pd.ewma(artist_price_trend.priceUSD.ix['2002':],span=50).plot(style='--', color='red')
    #plt.subplot(len(top_artists),2,i+1)
    #plt.subplot(1,2,2)
    fig1 = artist_price_trend.priceUSD.hist(bins = 25, orientation='horizontal',figsize=(12,4))
    fig1.axes.set_yticks(ticks = [])
    plt.suptitle('%s auction prices over time' % artist,fontsize=20)

# %%
def artists_works_plot(artist):
    art_price_trend = df[df.artistName == artist][['date','priceUSD','artTitle','images','auctionDate']]
    art_price_trend = art_price_trend[art_price_trend.date != u'']
    art_price_trend.date = art_price_trend.date.str.findall('\d{4}').str.get(0)
    art_price_trend.date = art_price_trend.date.astype('int64')
    
    top_pieces = art_price_trend.sort('priceUSD',ascending=False).iloc[:3]
    try:
        DOB = int(df[df.artistName == artist]['artistDOB'].iloc[0])
    except ValueError:
        DOB = art_price_trend.date.mean() - 50
    try:
        DOD = int(df[df.artistName == artist]['artistDOD'].iloc[0])
    except ValueError:
        DOD = art_price_trend.date.mean() + 50 
    try:
        top_pieces.images = top_pieces.images.apply(pd.Series)[0].apply(pd.Series).path
    except KeyError:
        print 'No images available'
    #plt.subplot(1, 1 + top_pieces.dropna().shape[0], 1)
    apt = art_price_trend[(art_price_trend.date > DOB) & (art_price_trend.date < DOD)]
    plt.scatter(apt.date, apt.priceUSD)
    for label, x, y in zip(top_pieces.artTitle, top_pieces.date, top_pieces.priceUSD):
        plt.annotate(label, xy = (x,y), ha='center')
    plt.ylabel('priceUSD')
    plt.xlabel('year')
    plt.title('%s art prices by composition year' % artist)
    return top_pieces

# %%
artist = top_artists[1]
artist_plot(artist)

# %%
top_pieces = artists_works_plot(artist)

# %%
    for i in range(top_pieces.dropna().shape[0]):
        #plt.subplot(1, 1 + top_pieces.dropna().shape[0], 1 + i)
        #plt.imshow(mpimg.imread(IMAGES_DIR + top_pieces.dropna().images.iloc[i]))
        print top_pieces.dropna().artTitle.iloc[i]
        print top_pieces.dropna().date.iloc[i]
        print 'Sold on ' + str(top_pieces.auctionDate.dropna().iloc[i]) + ' for $' + str(top_pieces.priceUSD.dropna().iloc[i])
        try:
            display(Image(IMAGES_DIR + top_pieces.dropna().images.iloc[i]))
        except TypeError:
            print 'no image available'
# Out:
# Sur le banc vert, Sanary
# 1911
# Sold on 2006-05-04 for $750000
# Nu allonge
# 1923
# Sold on 1990-06-27 for $540268

# %% [markdown]
# ## Auction Data

# %%
df.auctionCity.value_counts().ix[:50].plot(kind='bar', figsize=(12,4))
plt.title('Top 50 Auction Cities')

# %%
top_cities = df.auctionCity.value_counts().ix[:5].index.values
for i in range(len(top_cities)):
    plt.subplot(1,5,i)
    df[df['auctionCity'] == top_cities[i]]['auctionHouse'].value_counts().ix[:10].plot(kind='bar', figsize=(14,6))
    plt.title(top_cities[i])
plt.suptitle('Top Auction Houses within Top Cities', fontsize=20, y = 1.05)
plt.tight_layout()

# %%
top_cities = df.auctionCity.value_counts().ix[:5].index
top_city_auctions = df[df.auctionCity.isin(top_cities)]

# %%
for i in range(len(top_cities)):
    auctions_over_time = df[df.auctionCity == top_cities[i]][['auctionDate', 'priceUSD']]
    auctions_over_time.auctionDate = pd.to_datetime(auctions_over_time.auctionDate)
    std = auctions_over_time.groupby('auctionDate').mean().std().values[0]
    auctions_over_time.groupby('auctionDate').mean().ix['2001':].plot(title='%s avg. sale price' % top_cities[i], ylim = (0,std))

# %%
test = df[(df.artistName == 'Henri Lebasque') & (df.artTitle == 'Sur la plage')]

# %%
test.dtypes
# Out:
# artTitle                 object
# artistDOB                object
# artistDOD                object
# artistID                  int64
# artistName               object
# artistNationality        object
# artistNationalityDOB     object
# auctionCity              object
# auctionDate              object
# auctionHouse             object
# date                     object
# description              object
# image_urls               object
# images                   object
# lotDescription           object
# lotNote                  object
# lotNumber                object
# lot_id                    int64
# markings                 object
# materials                object
# measurements             object
# originalCurrency         object
# priceEUR                float64
# priceGBP                  int64
# priceUSD                  int64
# url                      object
# dtype: object

# %%
test.measurements
# Out:
# 287      7.00 in. (17.78 cm.) (height) by 9.00 in. (22....
# 10147    4.00 in. (10.16 cm.) (height) by 5.00 in. (12....
# 10340    10.00 in. (25.40 cm.) (height) by 14.00 in. (3...
# 10392    9.00 in. (22.86 cm.) (height) by 11.00 in. (27...
# 11418    18.00 in. (45.72 cm.) (height) by 22.00 in. (5...
# 13429    7.00 in. (17.78 cm.) (height) by 9.00 in. (22....
# 13861    12.00 in. (30.48 cm.) (height) by 15.00 in. (3...
# 15160    9.00 in. (22.86 cm.) (height) by 12.00 in. (30...
# 15882    5.00 in. (12.70 cm.) (height) by 7.00 in. (17....
# 16318    8.00 in. (20.32 cm.) (height) by 11.00 in. (27...
# 16342    5.00 in. (12.70 cm.) (height) by 7.00 in. (17....
# 18558    11.00 in. (27.94 cm.) (height) by 14.00 in. (3...
# 18910    7.00 in. (17.78 cm.) (height) by 10.00 in. (25...
# 19287    4.00 in. (10.16 cm.) (height) by 6.00 in. (15....
# 20998    11.00 in. (27.94 cm.) (height) by 10.00 in. (2...
# 21622    7.00 in. (17.78 cm.) (height) by 13.00 in. (33...
# 22786    38.00 in. (96.52 cm.) (height) by 51.00 in. (1...
# 22893    9.00 in. (22.86 cm.) (height) by 13.00 in. (33...
# Name: measurements, dtype: object

# %%
s = test.measurements.str.findall('\d+.\d+').apply(lambda x: float(x[1])*float(x[3]))
s.sort()
s
# Out:
# 10147      129.0320
# 19287      154.8384
# 15882      225.8060
# 16342      225.8060
# 13429      406.4508
# 287        406.4508
# 18910      451.6120
# 16318      567.7408
# 21622      587.0956
# 10392      638.7084
# 15160      696.7728
# 20998      709.6760
# 22893      754.8372
# 10340      903.2240
# 18558      993.5464
# 13861     1161.2880
# 11418     2554.8336
# 22786    12503.2008
# Name: measurements, dtype: float64

# %%
test['area'] = test.measurements.str.findall('\d+.\d+').apply(lambda x: float(x[1])*float(x[3]))

# %%
test[['materials','area','images','description']]
# Out:
#                    materials        area  \
# 287           Works on Paper    406.4508
# 10147             watercolor    129.0320
# 10340         Works on Paper    903.2240
# 10392  pencil and watercolor    638.7084
# 11418          oil on canvas   2554.8336
# 13429         Works on Paper    406.4508
# 13861         Works on Paper   1161.2880
# 15160             watercolor    696.7728
# 15882  pencil and watercolor    225.8060
# 16318         Works on Paper    567.7408
# 16342             watercolor    225.8060
# 18558  pencil and watercolor    993.5464
# 18910         Works on Paper    451.6120
# 19287             watercolor    154.8384
# 20998             watercolor    709.6760
# 21622  pencil and watercolor    587.0956
# 22786          oil on canvas  12503.2008
# 22893             watercolor    754.8372
#
#                                                   images  \
# 287    [{u'url': u'http://artinfo-images-350.s3.amazo...
# 10147                                                 []
# 10340  [{u'url': u'http://artinfo-images-350.s3.amazo...
# 10392                                                 []
# 11418  [{u'url': u'http://artinfo-images-350.s3.amazo...
# 13429  [{u'url': u'http://artinfo-images-350.s3.amazo...
# 13861                                                 []
# 15160                                                 []
# 15882                                                 []
# 16318                                                 []
# 16342                                                 []
# 18558                                                 []
# 18910                                                 []
# 19287                                                 []
# 20998                                                 []
# 21622                                                 []
# 22786                                                 []
# 22893                                                 []
#
#                  description
# 287    s. W/C pencil pen ink
# 10147              mono. W/C
# 10340         s. graphite dr
# 10392          s. W/C pencil
# 11418                    NaN
# 13429         bears sig. W/C
# 13861     s. W/C gouache chl
# 15160                  s.W/C
# 15882          s. W/C pencil
# 16318         s. W/C, crayon
# 16342                 s. W/C
# 18558     s. W/C over pencil
# 18910            s. W/C, chl
# 19287                 s. W/C
# 20998                 s. W/C
# 21622          s. W/C pencil
# 22786                    NaN
# 22893                 s. W/C

# %%
df.ix[287]
# Out:
# artTitle                                                     Sur la plage
# artistDOB                                                            1865
# artistDOD                                                            1937
# artistID                                                           100259
# artistName                                                 Henri Lebasque
# artistNationality                                                  French
# artistNationalityDOB                                (French, 1865 - 1937)
# auctionCity                                                       Olympia
# auctionDate                                                    2004-03-24
# auctionHouse                                                    Sotheby's
# date
# description                                         s. W/C pencil pen ink
# image_urls              [http://artinfo-images-350.s3.amazonaws.com/SO...
# images                  [{u'url': u'http://artinfo-images-350.s3.amazo...
# lotDescription               Lot 4  - Sotheby's, Olympia (March 24, 2004)
# lotNote                 Impressionist & Modern Art                    ...
# lotNumber                                                               4
# lot_id                                                              21057
# markings                                                              NaN
# materials                                                  Works on Paper
# measurements            7.00 in. (17.78 cm.) (height) by 9.00 in. (22....
# originalCurrency                                       £ 2,800 GBP Hammer
# priceEUR                                                             4206
# priceGBP                                                             2800
# priceUSD                                                             5139
# url                       http://artsalesindex.artinfo.com/asi/lots/21057
# Name: 287, dtype: object

# %%
from skimage.measure import structural_similarity as ssim
from skimage import img_as_float
from skimage.transform import resize
from skimage.color import rgb2gray
from scipy import misc

# %%
image_paths = test.images.apply(pd.Series).dropna()[0].apply(lambda x: x['path']).values

# %%
images = map(lambda x: misc.imread(IMAGES_DIR + x), image_paths)

# %%
from skimage.io import Image, imshow

# %%
stamps = [rgb2gray(resize(x, (300,300))) for x in images]

# %%
img_as_float(stamps[0])
# Out:
# array([[ 0.84818783,  0.84485068,  0.8433338 , ...,  0.85919179,
#          0.8564614 ,  0.85555127],
#        [ 0.91700229,  0.9154598 ,  0.91279967, ...,  0.91936392,
#          0.91642275,  0.91544235],
#        [ 0.92294837,  0.92196797,  0.91797832, ...,  0.9111771 ,
#          0.90907471,  0.9087234 ],
#        ...,
#        [ 0.96008039,  0.95452484,  0.94642298, ...,  0.94219335,
#          0.94098746,  0.93827885],
#        [ 0.92267177,  0.92319856,  0.91978875, ...,  0.92188592,
#          0.92121148,  0.92141389],
#        [ 0.79798356,  0.8190887 ,  0.83538071, ...,  0.80281381,
#          0.81130836,  0.81598455]])

# %%
np.linalg.norm(np.fft.fft2(stamps[0]) - np.fft.fft2(stamps[3]))
# Out:
# 7728.8582123662482

# %%
from skimage.feature import hog
np.linalg.norm(hog(img_as_float(stamps[0]), normalise=True) - hog(img_as_float(stamps[3]), normalise=True))
# Out:
# 4.460419578034772

# %%
imshow(stamps[3])

# %%
imshow(stamps[0])
